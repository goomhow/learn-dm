# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.arange(10)

# %%
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
ax1.hist(np.random.randn(100),bins=20,color='k')
# Out:
# (array([ 1.,  3.,  5.,  5.,  5.,  7.,  9.,  5., 12., 10.,  6.,  6., 14.,
#          4.,  3.,  3.,  0.,  1.,  0.,  1.]),
#  array([-2.13680229, -1.89071324, -1.6446242 , -1.39853516, -1.15244612,
#         -0.90635708, -0.66026804, -0.414179  , -0.16808995,  0.07799909,
#          0.32408813,  0.57017717,  0.81626621,  1.06235525,  1.30844429,
#          1.55453333,  1.80062238,  2.04671142,  2.29280046,  2.5388895 ,
#          2.78497854]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30),np.arange(30) + 3*np.random.randn(30))

# %%
fig,axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026D8F39A320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026D909422B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026D909116D8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026D9176F9B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026D917FE550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026D917E8080>]],
#       dtype=object)

# %%
axes[0,0]

# %%
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)

# %%
plt.subplots_adjust(wspace=0,hspace=0)

# %%
plt?

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
axes = plt.subplot(1,1,1)

# %%
axes.plot(randn(30).cumsum(),'ko--')

# %%
# %matplotlib notebook

# %%
axes

# %%
# %matplotlib notebook

# %%
clear

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(),'ko--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(randn(30).cumsum(),color='k',linestyle='dashed',marker='o')

# %%
data = randn(30).cumsum()

# %%
plt.plot(data,'k--',label='Default')

# %%
plt.plot(data,'k--',drawstyle='steps-post',label='steps-post')

# %%
plt.plot(data,'k--',drawstyle='steps-post')

# %%
plt.legend(loc='best')

# %%
# %matplotlib notebook

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from numpy.random import randn

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0,250,500,750,1000])

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')

# %%
ax.set_title('My first plot'.title())
# Out:
# Text(0.5,1,'My First Plot')

# %%
ax.set_xlabel("Stages")
# Out:
# Text(0.5,10.7639,'Stages')

# %%
props = {'title':'my first plot'.title(),'xlabel':'Stages'}

# %%
ax.set(**props)
# Out:
# [Text(0.5,-12.4461,'Stages'), Text(0.5,1,'My First Plot')]

# %%
clear

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(randn(1000).cumsum(),'k',label='one')

# %%
ax.plot(randn(1000).cumsum(),'k--',label='two')

# %%
ax.plot(randn(1000).cumsum(),'k.',label='three')

# %%
ax.legend(loc='best')

# %%
ax.legend?

# %%
ax.text(100,30,'Hello world')
# Out:
# Text(100,30,'Hello world')

# %%
ax.arrow(0,30,60,10)

# %%
from datetime import datetime

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
from numpy.random import randn

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
import pandas as pd
data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

# %%
data
# Out:
#                 SPX
# 1990-02-01   328.79
# 1990-02-02   330.92
# 1990-02-05   331.85
# 1990-02-06   329.66
# 1990-02-07   333.75
# 1990-02-08   332.96
# 1990-02-09   333.62
# 1990-02-12   330.08
# 1990-02-13   331.02
# 1990-02-14   332.01
# 1990-02-15   334.89
# 1990-02-16   332.72
# 1990-02-20   327.99
# 1990-02-21   327.67
# 1990-02-22   325.70
# 1990-02-23   324.15
# 1990-02-26   328.67
# 1990-02-27   330.26
# 1990-02-28   331.89
# 1990-03-01   332.74
# 1990-03-02   335.54
# 1990-03-05   333.74
# 1990-03-06   337.93
# 1990-03-07   336.95
# 1990-03-08   340.27
# 1990-03-09   337.93
# 1990-03-12   338.67
# 1990-03-13   336.00
# 1990-03-14   336.87
# 1990-03-15   338.07
# ...             ...
# 2011-09-02  1173.97
# 2011-09-06  1165.24
# 2011-09-07  1198.62
# 2011-09-08  1185.90
# 2011-09-09  1154.23
# 2011-09-12  1162.27
# 2011-09-13  1172.87
# 2011-09-14  1188.68
# 2011-09-15  1209.11
# 2011-09-16  1216.01
# 2011-09-19  1204.09
# 2011-09-20  1202.09
# 2011-09-21  1166.76
# 2011-09-22  1129.56
# 2011-09-23  1136.43
# 2011-09-26  1162.95
# 2011-09-27  1175.38
# 2011-09-28  1151.06
# 2011-09-29  1160.40
# 2011-09-30  1131.42
# 2011-10-03  1099.23
# 2011-10-04  1123.95
# 2011-10-05  1144.03
# 2011-10-06  1164.97
# 2011-10-07  1155.46
# 2011-10-10  1194.89
# 2011-10-11  1195.54
# 2011-10-12  1207.25
# 2011-10-13  1203.66
# 2011-10-14  1224.58
#
# [5472 rows x 1 columns]

# %%
spx.plot(ax = ax,style='k-')

# %%
crisis_data = [
(datetime(2007, 10, 11), 'Peak of bull market'),
(datetime(2008, 3, 12), 'Bear Stearns Fails'),
(datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

# %%
spx.asof?

# %%
for date,mark in crisis_data:
    ax.annotate(mark,
                xy=(date,spx.asof(date)+75),
                xytext=(date,spx.asof(date)+225),
                arrowprops={'facecolor':'black','headwidth':4,'width':2,'headlength':4},
                horizontalalignment='left', verticalalignment='top'
               )

# %%
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600,1800])
# Out:
# (600, 1800)

# %%
ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5,1,'Important dates in the 2008-2009 financial crisis')

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
rect = plt.Rectangle((0.2,0.2),0.1,0.2,color='k',alpha=0.3)

# %%
plt.show()

# %%
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)

# %%
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
color='g', alpha=0.5)

# %%
ax.add_patch(rect)

# %%
ax.add_patch(circ)

# %%
ax.add_patch(pgon)

# %%
plt.savefig('test.svg',dpi=400,bbox_inches='tight')

# %%
import numpy as np
s = pd.Series(np.random.randn(10).cumsum(),
index=np.arange(0, 100, 10))

# %%
s.plot()

# %%
s.plot?

# %%
In [62]: df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
....: columns=['A', 'B', 'C', 'D'],
....: index=np.arange(0, 100, 10))

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot(subplots=True,sharex=True,sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000295A282A2E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000295A20E0978>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000295A495BDA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000295A47F2780>],
#       dtype=object)

# %%
fig,axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
In [65]: data = pd.Series(np.random.rand(16),
index=list('abcdefghijklmnop'))

# %%
data
# Out:
# a    0.870178
# b    0.370807
# c    0.500166
# d    0.792243
# e    0.787742
# f    0.068619
# g    0.959987
# h    0.242223
# i    0.588988
# j    0.299823
# k    0.716136
# l    0.330907
# m    0.914343
# n    0.312208
# o    0.340260
# p    0.676794
# dtype: float64

# %%
data.plot.bar(ax=axes[0],color='k',alpha=0.7)

# %%
data.plot.barh(ax=axes[1],alpha=0.7)

# %%
In [69]: df = pd.DataFrame(np.random.rand(6, 4),
....: index=['one', 'two', 'three', 'four',
'five', 'six'],
....: columns=pd.Index(['A', 'B', 'C', 'D'],
name='Genus'))

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.674017  0.947417  0.623632  0.417830
# two    0.059236  0.388365  0.140495  0.112893
# three  0.415993  0.743459  0.654303  0.050234
# four   0.579114  0.038907  0.629652  0.098256
# five   0.239321  0.082475  0.440807  0.051303
# six    0.182737  0.978081  0.078934  0.651337

# %%
df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.bar(stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.A.value_counts().plot.bar()

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# 5         25.29  4.71     No   Sun  Dinner     4
# 6          8.77  2.00     No   Sun  Dinner     2
# 7         26.88  3.12     No   Sun  Dinner     4
# 8         15.04  1.96     No   Sun  Dinner     2
# 9         14.78  3.23     No   Sun  Dinner     2
# 10        10.27  1.71     No   Sun  Dinner     2
# 11        35.26  5.00     No   Sun  Dinner     4
# 12        15.42  1.57     No   Sun  Dinner     2
# 13        18.43  3.00     No   Sun  Dinner     4
# 14        14.83  3.02     No   Sun  Dinner     2
# 15        21.58  3.92     No   Sun  Dinner     2
# 16        10.33  1.67     No   Sun  Dinner     3
# 17        16.29  3.71     No   Sun  Dinner     3
# 18        16.97  3.50     No   Sun  Dinner     3
# 19        20.65  3.35     No   Sat  Dinner     3
# 20        17.92  4.08     No   Sat  Dinner     2
# 21        20.29  2.75     No   Sat  Dinner     2
# 22        15.77  2.23     No   Sat  Dinner     2
# 23        39.42  7.58     No   Sat  Dinner     4
# 24        19.82  3.18     No   Sat  Dinner     2
# 25        17.81  2.34     No   Sat  Dinner     4
# 26        13.37  2.00     No   Sat  Dinner     2
# 27        12.69  2.00     No   Sat  Dinner     2
# 28        21.70  4.30     No   Sat  Dinner     2
# 29        19.65  3.00     No   Sat  Dinner     2
# ..          ...   ...    ...   ...     ...   ...
# 214       28.17  6.50    Yes   Sat  Dinner     3
# 215       12.90  1.10    Yes   Sat  Dinner     2
# 216       28.15  3.00    Yes   Sat  Dinner     5
# 217       11.59  1.50    Yes   Sat  Dinner     2
# 218        7.74  1.44    Yes   Sat  Dinner     2
# 219       30.14  3.09    Yes   Sat  Dinner     4
# 220       12.16  2.20    Yes   Fri   Lunch     2
# 221       13.42  3.48    Yes   Fri   Lunch     2
# 222        8.58  1.92    Yes   Fri   Lunch     1
# 223       15.98  3.00     No   Fri   Lunch     3
# 224       13.42  1.58    Yes   Fri   Lunch     2
# 225       16.27  2.50    Yes   Fri   Lunch     2
# 226       10.09  2.00    Yes   Fri   Lunch     2
# 227       20.45  3.00     No   Sat  Dinner     4
# 228       13.28  2.72     No   Sat  Dinner     2
# 229       22.12  2.88    Yes   Sat  Dinner     2
# 230       24.01  2.00    Yes   Sat  Dinner     4
# 231       15.69  3.00    Yes   Sat  Dinner     3
# 232       11.61  3.39     No   Sat  Dinner     2
# 233       10.77  1.47     No   Sat  Dinner     2
# 234       15.53  3.00    Yes   Sat  Dinner     2
# 235       10.07  1.25     No   Sat  Dinner     2
# 236       12.60  1.00    Yes   Sat  Dinner     2
# 237       32.83  1.17    Yes   Sat  Dinner     2
# 238       35.83  4.67     No   Sat  Dinner     3
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
party_counts = pd.crosstab(tips['day'], tips['size'])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
party_counts = party_counts.loc[:, 2:5]

# %%
normal = party_counts.div(party_counts.sum(1),0)

# %%
normal
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
normal.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] -
tips['tip'])

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# 5         25.29  4.71     No   Sun  Dinner     4  0.228863
# 6          8.77  2.00     No   Sun  Dinner     2  0.295421
# 7         26.88  3.12     No   Sun  Dinner     4  0.131313
# 8         15.04  1.96     No   Sun  Dinner     2  0.149847
# 9         14.78  3.23     No   Sun  Dinner     2  0.279654
# 10        10.27  1.71     No   Sun  Dinner     2  0.199766
# 11        35.26  5.00     No   Sun  Dinner     4  0.165235
# 12        15.42  1.57     No   Sun  Dinner     2  0.113357
# 13        18.43  3.00     No   Sun  Dinner     4  0.194426
# 14        14.83  3.02     No   Sun  Dinner     2  0.255715
# 15        21.58  3.92     No   Sun  Dinner     2  0.221971
# 16        10.33  1.67     No   Sun  Dinner     3  0.192841
# 17        16.29  3.71     No   Sun  Dinner     3  0.294913
# 18        16.97  3.50     No   Sun  Dinner     3  0.259837
# 19        20.65  3.35     No   Sat  Dinner     3  0.193642
# 20        17.92  4.08     No   Sat  Dinner     2  0.294798
# 21        20.29  2.75     No   Sat  Dinner     2  0.156784
# 22        15.77  2.23     No   Sat  Dinner     2  0.164697
# 23        39.42  7.58     No   Sat  Dinner     4  0.238065
# 24        19.82  3.18     No   Sat  Dinner     2  0.191106
# 25        17.81  2.34     No   Sat  Dinner     4  0.151261
# 26        13.37  2.00     No   Sat  Dinner     2  0.175901
# 27        12.69  2.00     No   Sat  Dinner     2  0.187091
# 28        21.70  4.30     No   Sat  Dinner     2  0.247126
# 29        19.65  3.00     No   Sat  Dinner     2  0.180180
# ..          ...   ...    ...   ...     ...   ...       ...
# 214       28.17  6.50    Yes   Sat  Dinner     3  0.299954
# 215       12.90  1.10    Yes   Sat  Dinner     2  0.093220
# 216       28.15  3.00    Yes   Sat  Dinner     5  0.119284
# 217       11.59  1.50    Yes   Sat  Dinner     2  0.148662
# 218        7.74  1.44    Yes   Sat  Dinner     2  0.228571
# 219       30.14  3.09    Yes   Sat  Dinner     4  0.114233
# 220       12.16  2.20    Yes   Fri   Lunch     2  0.220884
# 221       13.42  3.48    Yes   Fri   Lunch     2  0.350101
# 222        8.58  1.92    Yes   Fri   Lunch     1  0.288288
# 223       15.98  3.00     No   Fri   Lunch     3  0.231125
# 224       13.42  1.58    Yes   Fri   Lunch     2  0.133446
# 225       16.27  2.50    Yes   Fri   Lunch     2  0.181554
# 226       10.09  2.00    Yes   Fri   Lunch     2  0.247219
# 227       20.45  3.00     No   Sat  Dinner     4  0.171920
# 228       13.28  2.72     No   Sat  Dinner     2  0.257576
# 229       22.12  2.88    Yes   Sat  Dinner     2  0.149688
# 230       24.01  2.00    Yes   Sat  Dinner     4  0.090868
# 231       15.69  3.00    Yes   Sat  Dinner     3  0.236407
# 232       11.61  3.39     No   Sat  Dinner     2  0.412409
# 233       10.77  1.47     No   Sat  Dinner     2  0.158065
# 234       15.53  3.00    Yes   Sat  Dinner     2  0.239425
# 235       10.07  1.25     No   Sat  Dinner     2  0.141723
# 236       12.60  1.00    Yes   Sat  Dinner     2  0.086207
# 237       32.83  1.17    Yes   Sat  Dinner     2  0.036955
# 238       35.83  4.67     No   Sat  Dinner     3  0.149872
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='tip_pct',y='day',data=tips,orient='h')

# %%
sns.barplot(x='tip_pct',y='day',hue='time',data=tips,orient='h')

# %%
sns.set_style('whitegrid')

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
tips['tip_pct'].plot.hist(ax=ax,bins=50)

# %%
tips.tip_pct.plot.density()

# %%
In [96]: comp1 = np.random.normal(0, 1, size=200)
In [97]: comp2 = np.random.normal(10, 2, size=200)
In [98]: values = pd.Series(np.concatenate([comp1, comp2]))

# %%
values
# Out:
# 0       1.126618
# 1       0.903866
# 2       0.167497
# 3       0.635300
# 4       0.075085
# 5      -1.423800
# 6       1.466205
# 7      -0.838222
# 8      -0.420305
# 9      -2.777659
# 10      0.333194
# 11      1.190885
# 12     -0.021663
# 13      0.481963
# 14     -0.043172
# 15     -1.137656
# 16     -1.387325
# 17     -1.198504
# 18      1.139235
# 19      0.982940
# 20      1.849111
# 21      1.498929
# 22     -0.990901
# 23     -1.084613
# 24     -0.492408
# 25     -0.997238
# 26     -1.302954
# 27      0.148456
# 28      0.134909
# 29     -0.856449
#          ...
# 370    11.399899
# 371     9.631551
# 372     7.461080
# 373    10.670084
# 374    11.168683
# 375     7.932860
# 376     9.160706
# 377     9.133014
# 378     9.023326
# 379    11.470900
# 380    11.418986
# 381     9.201627
# 382    10.664208
# 383     9.668770
# 384    12.459296
# 385     5.929973
# 386    10.314057
# 387     9.493422
# 388     9.745759
# 389    10.276604
# 390     9.808513
# 391    11.519178
# 392    11.575881
# 393    10.851361
# 394    10.767657
# 395    10.510462
# 396     8.264522
# 397    10.600842
# 398     6.467241
# 399     9.731152
# Length: 400, dtype: float64

# %%
sns.distplot(values,bins=100)

# %%
ax.clear()

# %%
sns.distplot(values,bins=100)

# %%
In [100]: macro = pd.read_csv('examples/macrodata.csv')
In [101]: data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
In [102]: trans_data = np.log(data).diff().dropna()

# %%
 trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
ax.clear()
sns.regplot('m1','unemp',data=trans_data)

# %%
plt.title('Changes in log %s versus log %s' % ('m1',
'unemp'))
# Out:
# Text(0.5,1,'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data,diag_kind='kde',plot_kws=dict(alpha=0.3))
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
In [108]: sns.factorplot(x='day', y='tip_pct', hue='time',
col='smoker',
.....: kind='bar', data=tips[tips.tip_pct < 1])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sns.factorplot(x='day',y='tip_pct',row='time',col='smoker',kind='bar',data=tips[tips['tip_pct']<1])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sns.factorplot(x='day',y='tip_pct',kind='box',data=tips[tips.tip_pct<0.5])
# Out:
# <img src="data:image/png;base64,..." width="400">
